# %%
# %pip install -U langchain-community

# %%
import os
from google.colab import userdata

# Set the environment variable for the Hugging Face API token
os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get('hugging_2')

# %%
from langchain.llms import HuggingFaceHub
llm = HuggingFaceHub(repo_id="google/flan-t5-base", task="text2text-generation")

# %%
from langchain.document_loaders import TextLoader
loader = TextLoader("/content/training_data.txt")
documents = loader.load()

for doc in documents:
    print(doc.page_content)
# Out:
# Artificial Intelligence is transforming industries.
# Natural Language Processing enables machines to understand human language.
# Machine Learning helps computers learn from data.
# Deep Learning uses neural networks to make predictions.
# Generative AI can create text, images, and music.
# Language models like GPT-2 can generate human-like text.
# Fine-tuning helps customize models for specific tasks.
# Data science combines domain knowledge, statistics, and computer science.
# Python is widely used for data science and machine learning.
# Transformers revolutionized the field of NLP.

# %%
from langchain.document_loaders import CSVLoader
loader = CSVLoader(file_path='/content/titanic-training-data.csv')
documents = loader.load()
for doc in documents:
    print(doc.page_content)
# Out:
# PassengerId: 1
# Survived: 0
# Pclass: 3
# Name: Braund, Mr. Owen Harris
# Sex: male
# Age: 22
# SibSp: 1
# Parch: 0
# Ticket: A/5 21171
# Fare: 7.25
# Cabin:
# Embarked: S
# PassengerId: 2
# Survived: 1
# Pclass: 1
# Name: Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Sex: female
# Age: 38
# SibSp: 1
# Parch: 0
# Ticket: PC 17599
# Fare: 71.2833
# Cabin: C85
# Embarked: C
# PassengerId: 3
# Survived: 1
# Pclass: 3
# Name: Heikkinen, Miss. Laina
# Sex: female
# Age: 26
# SibSp: 0
# Parch: 0
# Ticket: STON/O2. 3101282
# Fare: 7.925
# Cabin:
# Embarked: S
# PassengerId: 4
# Survived: 1
# Pclass: 1
# Name: Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex: female
# Age: 35
# SibSp: 1
# Parch: 0
# Ticket: 113803
# Fare: 53.1
# Cabin: C123
# Embarked: S
# PassengerId: 5
# Survived: 0
# Pclass: 3
# Name: Allen, Mr. William Henry
# Sex: male
# Age: 35
# SibSp: 0
# Parch: 0
# Ticket: 373450
# Fare: 8.05
# Cabin:
# Embarked: S
# PassengerId: 6
# Survived: 0
# Pclass: 3
# ...

# %%
from langchain.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://example.com")
documents = loader.load()
for doc in documents:
    print(doc.page_content)
# Out:
# Example Domain
#
#
#
#
#
#
#
# Example Domain
# This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.
# More information...

# %%
pip install wikipedia
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=76e7c97f2fb9119971fec1b1a4025c72863a32563e6f3432b88620d929a7e63c
#   Stored in directory: /root/.cache/pip/wheels/8f/ab/cb/45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# ...

# %%
from langchain.document_loaders import WikipediaLoader
loader = WikipediaLoader(query="Mahatma Gandhi", lang="en")
documents = loader.load()
for doc in documents:
    print(doc.page_content)
# Out:
# Mohandas Karamchand Gandhi (2 October 1869 – 30 January 1948) was an Indian lawyer, anti-colonial nationalist, and political ethicist who employed nonviolent resistance to lead the successful campaign for India's independence from British rule. He inspired movements for civil rights and freedom across the world. The honorific Mahātmā (from Sanskrit, meaning great-souled, or venerable), first applied to him in South Africa in 1914, is now used throughout the world.
# ...

# %%
pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.7/309.7 kB 6.6 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("/content/Mentor_17 years_AI.pdf")
documents = loader.load()
for doc in documents:
    print(doc.page_content)
# Out:
# Dr. Premalatha. T
# 16 years of experience as Corporate Trainer (Artificial Intelligence/Analytics/Power BI/Tableau/S inference and
# creation of data insights as a Data Scientist.                         Techiegal.2022@gmail.com      +91 8072142507
# Chennai – 600122, TN
#
# WORK EXPERIENCE:
#
# o Trainer/Corporate Trainer on Artificial
# Intelligence and Machine Learning, Data
# Science, Business Analytics, Financial,
# Marketing, HR Analytics for IIT, IIM, ISB,
# Symbiosis Graduates (Till Present)
# o Lean Six Sigma Master Black Belt
# o AI Consultant, Freelancer (2019-Present)
# o Principal Data Scientist- Amazon,
# Flipkart and Walmart (2010-2019)
#
# • Strong understanding of Predictive modeling and
# Machine learning Algorithms– Linear Regression,
# Logistic Regression, KNN, Naïve Bayes
# Classifiers, Support Vector Machines, K Means
# Clustering, Hierarchical Clustering, Dimension
# Reduction-PCA, Random Forest, Decision Tress,
# Bagging, Boosting, Content based
# ...

# %%
from langchain.document_loaders import BSHTMLLoader
loader = BSHTMLLoader("html file")
documents = loader.load()

# %%
from langchain.text_splitter import CharacterTextSplitter

# Split the document into smaller chunks
text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=100)
docs = text_splitter.split_documents(documents)

# %%
from langchain.llms import HuggingFaceHub

llm = HuggingFaceHub(
    repo_id="google/flan-t5-base",
    task="text2text-generation",
    model_kwargs={"temperature": 0.5, "max_length": 200}
)

# %%
from langchain.chains.question_answering import load_qa_chain

# Create a basic QA chain using "stuff" method
qa_chain = load_qa_chain(llm, chain_type="stuff")
